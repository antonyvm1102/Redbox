# %%
import verwerking_try as vw
import matplotlib.pyplot as plt
import time

# %%
flname = r"C:\Users\mdk\Desktop\test\20180228103000000417.txt"
fld_path = r"C:\Users\mdk\Desktop\test"

start= time.time()
t,x,y,z = vw.obtain_data_general(flname)
dt = t[1]- t[0]
end = time.time()

print("%s seconds elapsed" %(end-start))
# Out:
# 73 lines where skipped
# 16.33072066307068 seconds elapsed

# %%
z=z[0:2**19]
print(len(z))

start= time.time()
ampl, freq = vw.FFT(z,dt)
end = time.time()

print("%s seconds elapsed" %(end-start))
# Out:
# 524288
# 0.0430302619934082 seconds elapsed

# %%
plt.plot(freq,ampl,'r')
plt.show()

# %%
# Out:
# 24.51053810119629 seconds elapsed

# %%
# Out:
# 524288
